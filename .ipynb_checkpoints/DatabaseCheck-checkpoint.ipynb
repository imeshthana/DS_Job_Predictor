# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ds_salaries1.csv')

# %% [markdown]
# ## Dataset Checking

# %%
data.shape
# Out:
# (9556, 11)

# %%
data.head()
# Out:
#    work_year experience_level employment_type         job_title  salary  \
# 0       2023               SE              FT     Data Engineer  234000
# 1       2023               SE              FT     Data Engineer  146000
# 2       2023               MI              FT    Data Scientist  199700
# 3       2023               MI              FT    Data Scientist   70800
# 4       2023               EN              FT  Research Analyst  179000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         234000                 US             0
# 1             USD         146000                 US             0
# 2             USD         199700                 US             0
# 3             USD          70800                 US             0
# 4             USD         179000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9556 entries, 0 to 9555
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9556 non-null   int64
#  1   experience_level    9556 non-null   object
#  2   employment_type     9556 non-null   object
#  3   job_title           9556 non-null   object
#  4   salary              9556 non-null   int64
#  5   salary_currency     9556 non-null   object
#  6   salary_in_usd       9556 non-null   int64
#  7   employee_residence  9556 non-null   object
#  8   remote_ratio        9556 non-null   int64
#  9   company_location    9556 non-null   object
#  10  company_size        9556 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 821.3+ KB

# %%
data.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  9556.000000  9.556000e+03    9556.000000   9556.000000
# mean   2022.758058  1.728261e+05  149592.456467     37.651737
# std       0.525501  4.382879e+05   64667.741321     47.850615
# min    2020.000000  1.400000e+04   15000.000000      0.000000
# 25%    2023.000000  1.052000e+05  105000.000000      0.000000
# 50%    2023.000000  1.440000e+05  142200.000000      0.000000
# 75%    2023.000000  1.900000e+05  186000.000000    100.000000
# max    2023.000000  3.040000e+07  750000.000000    100.000000

# %% [markdown]
# ## Check for null values

# %%
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## Feature Selection

# %%
data['company_location'].value_counts()
# Out:
# US    8252
# GB     459
# CA     228
# ES     115
# DE      73
#       ...
# EC       1
# QA       1
# MU       1
# GI       1
# MT       1
# Name: company_location, Length: 74, dtype: int64

# %%
# def add_company_location(region):
#     if region=='US' or region=='GB' or region=='CA' or region=='ES' or region=='DE' or region=='IN' or region=='FR':
#         return region
#     else:
#         return 'Other'

# # or region=='PT' or region=='AU' or region=='NL' or region=='BR' or region=='CO' or region=='GR' or region=='IT' or region=='MX' or region=='PL' or region=='EE'

# data['company_location'] = data['company_location'].apply(add_company_location)

# %%
data['employee_residence'].value_counts()
# Out:
# US    8203
# GB     452
# CA     226
# ES     119
# DE      66
#       ...
# EC       1
# AD       1
# QA       1
# MU       1
# MT       1
# Name: employee_residence, Length: 86, dtype: int64

# %%
# def add_employee_residence(region):
#     if region=='US' or region=='GB' or region=='CA' or region=='ES' or region=='DE' or region=='IN' or region=='FR':
#         return region
#     else:
#         return 'Other'

# # or region=='PT' or region=='AU' or region=='NL' or region=='IT' or region=='BR' or region=='GR' or region=='CO' or region=='MX' or region=='PL' or region=='NG'

# data['employee_residence'] = data['employee_residence'].apply(add_employee_residence)

# %%
data.head()
# Out:
#    work_year experience_level employment_type         job_title  salary  \
# 0       2023               SE              FT     Data Engineer  234000
# 1       2023               SE              FT     Data Engineer  146000
# 2       2023               MI              FT    Data Scientist  199700
# 3       2023               MI              FT    Data Scientist   70800
# 4       2023               EN              FT  Research Analyst  179000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         234000                 US             0
# 1             USD         146000                 US             0
# 2             USD         199700                 US             0
# 3             USD          70800                 US             0
# 4             USD         179000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %%
# data = pd.get_dummies(data, columns=['company_location'], prefix='company_location')

# %%
# data = pd.get_dummies(data, columns=['employee_residence'], prefix='employee_residence')

# %%
data.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 9551       2020               SE              FT            Data Scientist
# 9552       2021               MI              FT  Principal Data Scientist
# 9553       2020               EN              FT            Data Scientist
# 9554       2020               EN              CT     Business Data Analyst
# 9555       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 9551   412000             USD         412000                 US           100
# 9552   151000             USD         151000                 US           100
# 9553   105000             USD         105000                 US           100
# 9554   100000             USD         100000                 US           100
# 9555  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 9551               US            L
# 9552               US            L
# 9553               US            S
# 9554               US            L
# 9555               IN            L

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['experience_level'] = le.fit_transform(data['experience_level'])
data['work_year'] = le.fit_transform(data['work_year'])
data['employment_type'] = le.fit_transform(data['employment_type'])
data['job_title'] = le.fit_transform(data['job_title'])
data['salary_in_usd'] = le.fit_transform(data['salary_in_usd'])
data['salary_currency'] = le.fit_transform(data['salary_currency'])
data['employee_residence'] = le.fit_transform(data['employee_residence'])
data['company_location'] = le.fit_transform(data['company_location'])
data['company_size'] = le.fit_transform(data['company_size'])
data['remote_ratio'] = le.fit_transform(data['remote_ratio'])

data.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0          3                 3                2         44  234000
# 1          3                 3                2         44  146000
# 2          3                 2                2         69  199700
# 3          3                 2                2         69   70800
# 4          3                 0                2        118  179000
#
#    salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0               20           1625                  82             0
# 1               20           1038                  82             0
# 2               20           1439                  82             0
# 3               20            348                  82             0
# 4               20           1297                  82             0
#
#    company_location  company_size
# 0                72             1
# 1                72             1
# 2                72             1
# 3                72             1
# 4                72             1

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## So we should remove 'employee_residence' feature
